# %%
# Dependencies
import csv
import matplotlib.pyplot as plt
import requests
import pandas as pd
import time
#from config import api_key

#print(api_key)

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/forecast?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid=c307a28aeb926aea5ca576d761bc611b&units={units}&q="

# %%
cities = ['Quito']

# %%
len(cities)
# Out:
# 1

# %%
# set up lists to hold reponse info
city_id = []
city_name = []
city_lat = []
city_lon = []
country = []
city_time = []

# define day_one_time_one arrays
date_one_time_one = []
date_one_time_one_temp = []
date_one_time_one_temp_min = []
date_one_time_one_temp_max =[]
date_one_time_one_pressure = []
date_one_time_one_sea_level = []
date_one_time_one_grnd_level = []
date_one_time_one_humidity = []
date_one_time_one_wind_speed = []
date_one_time_one_wind_direction = []

# define day_one_time_two arrays
date_one_time_two = []
date_one_time_two_temp = []
date_one_time_two_temp_min = []
date_one_time_two_temp_max =[]
date_one_time_two_pressure = []
date_one_time_two_sea_level = []
date_one_time_two_grnd_level = []
date_one_time_two_humidity = []
date_one_time_two_wind_speed = []
date_one_time_two_wind_direction = []


# define day_one_time_three arrays
date_one_time_three = []
date_one_time_three_temp = []
date_one_time_three_temp_min = []
date_one_time_three_temp_max =[]
date_one_time_three_pressure = []
date_one_time_three_sea_level = []
date_one_time_three_grnd_level = []
date_one_time_three_humidity = []
date_one_time_three_wind_speed = []
date_one_time_three_wind_direction = []

# define day_one_time_four arrays
date_one_time_four = []
date_one_time_four_temp = []
date_one_time_four_temp_min = []
date_one_time_four_temp_max =[]
date_one_time_four_pressure = []
date_one_time_four_sea_level = []
date_one_time_four_grnd_level = []
date_one_time_four_humidity = []
date_one_time_four_wind_speed = []
date_one_time_four_wind_direction = []

# define day_one_time_five arrays
date_one_time_five = []
date_one_time_five_temp = []
date_one_time_five_temp_min = []
date_one_time_five_temp_max =[]
date_one_time_five_pressure = []
date_one_time_five_sea_level = []
date_one_time_five_grnd_level = []
date_one_time_five_humidity = []
date_one_time_five_wind_speed = []
date_one_time_five_wind_direction = []

# define day_one_time_six arrays
date_one_time_six = []
date_one_time_six_temp = []
date_one_time_six_temp_min = []
date_one_time_six_temp_max =[]
date_one_time_six_pressure = []
date_one_time_six_sea_level = []
date_one_time_six_grnd_level = []
date_one_time_six_humidity = []
date_one_time_six_wind_speed = []
date_one_time_six_wind_direction = []

# define day_one_time_seven arrays
date_one_time_seven = []
date_one_time_seven_temp = []
date_one_time_seven_temp_min = []
date_one_time_seven_temp_max =[]
date_one_time_seven_pressure = []
date_one_time_seven_sea_level = []
date_one_time_seven_grnd_level = []
date_one_time_seven_humidity = []
date_one_time_seven_wind_speed = []
date_one_time_seven_wind_direction = []

# define day_one_time_eight arrays
date_one_time_eight = []
date_one_time_eight_temp = []
date_one_time_eight_temp_min = []
date_one_time_eight_temp_max =[]
date_one_time_eight_pressure = []
date_one_time_eight_sea_level = []
date_one_time_eight_grnd_level = []
date_one_time_eight_humidity = []
date_one_time_eight_wind_speed = []
date_one_time_eight_wind_direction = []




# define day_two_time_one arrays
date_two_time_one = []
date_two_time_one_temp = []
date_two_time_one_temp_min = []
date_two_time_one_temp_max =[]
date_two_time_one_pressure = []
date_two_time_one_sea_level = []
date_two_time_one_grnd_level = []
date_two_time_one_humidity = []
date_two_time_one_wind_speed = []
date_two_time_one_wind_direction = []

# define day_two_time_two arrays
date_two_time_two = []
date_two_time_two_temp = []
date_two_time_two_temp_min = []
date_two_time_two_temp_max =[]
date_two_time_two_pressure = []
date_two_time_two_sea_level = []
date_two_time_two_grnd_level = []
date_two_time_two_humidity = []
date_two_time_two_wind_speed = []
date_two_time_two_wind_direction = []


# define day_two_time_three arrays
date_two_time_three = []
date_two_time_three_temp = []
date_two_time_three_temp_min = []
date_two_time_three_temp_max =[]
date_two_time_three_pressure = []
date_two_time_three_sea_level = []
date_two_time_three_grnd_level = []
date_two_time_three_humidity = []
date_two_time_three_wind_speed = []
date_two_time_three_wind_direction = []

# define day_two_time_four arrays
date_two_time_four = []
date_two_time_four_temp = []
date_two_time_four_temp_min = []
date_two_time_four_temp_max =[]
date_two_time_four_pressure = []
date_two_time_four_sea_level = []
date_two_time_four_grnd_level = []
date_two_time_four_humidity = []
date_two_time_four_wind_speed = []
date_two_time_four_wind_direction = []

# define day_two_time_five arrays
date_two_time_five = []
date_two_time_five_temp = []
date_two_time_five_temp_min = []
date_two_time_five_temp_max =[]
date_two_time_five_pressure = []
date_two_time_five_sea_level = []
date_two_time_five_grnd_level = []
date_two_time_five_humidity = []
date_two_time_five_wind_speed = []
date_two_time_five_wind_direction = []

# define day_two_time_six arrays
date_two_time_six = []
date_two_time_six_temp = []
date_two_time_six_temp_min = []
date_two_time_six_temp_max =[]
date_two_time_six_pressure = []
date_two_time_six_sea_level = []
date_two_time_six_grnd_level = []
date_two_time_six_humidity = []
date_two_time_six_wind_speed = []
date_two_time_six_wind_direction = []


# define day_two_time_seven arrays
date_two_time_seven = []
date_two_time_seven_temp = []
date_two_time_seven_temp_min = []
date_two_time_seven_temp_max =[]
date_two_time_seven_pressure = []
date_two_time_seven_sea_level = []
date_two_time_seven_grnd_level = []
date_two_time_seven_humidity = []
date_two_time_seven_wind_speed = []
date_two_time_seven_wind_direction = []

# define day_two_time_eight arrays
date_two_time_eight = []
date_two_time_eight_temp = []
date_two_time_eight_temp_min = []
date_two_time_eight_temp_max =[]
date_two_time_eight_pressure = []
date_two_time_eight_sea_level = []
date_two_time_eight_grnd_level = []
date_two_time_eight_humidity = []
date_two_time_eight_wind_speed = []
date_two_time_eight_wind_direction = []







# define day_three_time_one arrays
date_three_time_one = []
date_three_time_one_temp = []
date_three_time_one_temp_min = []
date_three_time_one_temp_max =[]
date_three_time_one_pressure = []
date_three_time_one_sea_level = []
date_three_time_one_grnd_level = []
date_three_time_one_humidity = []
date_three_time_one_wind_speed = []
date_three_time_one_wind_direction = []

# define day_three_time_two arrays
date_three_time_two = []
date_three_time_two_temp = []
date_three_time_two_temp_min = []
date_three_time_two_temp_max =[]
date_three_time_two_pressure = []
date_three_time_two_sea_level = []
date_three_time_two_grnd_level = []
date_three_time_two_humidity = []
date_three_time_two_wind_speed = []
date_three_time_two_wind_direction = []


# define day_three_time_three arrays
date_three_time_three = []
date_three_time_three_temp = []
date_three_time_three_temp_min = []
date_three_time_three_temp_max =[]
date_three_time_three_pressure = []
date_three_time_three_sea_level = []
date_three_time_three_grnd_level = []
date_three_time_three_humidity = []
date_three_time_three_wind_speed = []
date_three_time_three_wind_direction = []

# define day_three_time_four arrays
date_three_time_four = []
date_three_time_four_temp = []
date_three_time_four_temp_min = []
date_three_time_four_temp_max =[]
date_three_time_four_pressure = []
date_three_time_four_sea_level = []
date_three_time_four_grnd_level = []
date_three_time_four_humidity = []
date_three_time_four_wind_speed = []
date_three_time_four_wind_direction = []

# define day_three_time_five arrays
date_three_time_five = []
date_three_time_five_temp = []
date_three_time_five_temp_min = []
date_three_time_five_temp_max =[]
date_three_time_five_pressure = []
date_three_time_five_sea_level = []
date_three_time_five_grnd_level = []
date_three_time_five_humidity = []
date_three_time_five_wind_speed = []
date_three_time_five_wind_direction = []

# define day_three_time_six arrays
date_three_time_six = []
date_three_time_six_temp = []
date_three_time_six_temp_min = []
date_three_time_six_temp_max =[]
date_three_time_six_pressure = []
date_three_time_six_sea_level = []
date_three_time_six_grnd_level = []
date_three_time_six_humidity = []
date_three_time_six_wind_speed = []
date_three_time_six_wind_direction = []


# define day_three_time_seven arrays
date_three_time_seven = []
date_three_time_seven_temp = []
date_three_time_seven_temp_min = []
date_three_time_seven_temp_max =[]
date_three_time_seven_pressure = []
date_three_time_seven_sea_level = []
date_three_time_seven_grnd_level = []
date_three_time_seven_humidity = []
date_three_time_seven_wind_speed = []
date_three_time_seven_wind_direction = []


# define day_three_time_eight arrays
date_three_time_eight = []
date_three_time_eight_temp = []
date_three_time_eight_temp_min = []
date_three_time_eight_temp_max =[]
date_three_time_eight_pressure = []
date_three_time_eight_sea_level = []
date_three_time_eight_grnd_level = []
date_three_time_eight_humidity = []
date_three_time_eight_wind_speed = []
date_three_time_eight_wind_direction = []







# define day_four_time_one arrays
date_four_time_one = []
date_four_time_one_temp = []
date_four_time_one_temp_min = []
date_four_time_one_temp_max =[]
date_four_time_one_pressure = []
date_four_time_one_sea_level = []
date_four_time_one_grnd_level = []
date_four_time_one_humidity = []
date_four_time_one_wind_speed = []
date_four_time_one_wind_direction = []

# define day_four_time_two arrays
date_four_time_two = []
date_four_time_two_temp = []
date_four_time_two_temp_min = []
date_four_time_two_temp_max =[]
date_four_time_two_pressure = []
date_four_time_two_sea_level = []
date_four_time_two_grnd_level = []
date_four_time_two_humidity = []
date_four_time_two_wind_speed = []
date_four_time_two_wind_direction = []


# define day_four_time_three arrays
date_four_time_three = []
date_four_time_three_temp = []
date_four_time_three_temp_min = []
date_four_time_three_temp_max =[]
date_four_time_three_pressure = []
date_four_time_three_sea_level = []
date_four_time_three_grnd_level = []
date_four_time_three_humidity = []
date_four_time_three_wind_speed = []
date_four_time_three_wind_direction = []

# define day_four_time_four arrays
date_four_time_four = []
date_four_time_four_temp = []
date_four_time_four_temp_min = []
date_four_time_four_temp_max =[]
date_four_time_four_pressure = []
date_four_time_four_sea_level = []
date_four_time_four_grnd_level = []
date_four_time_four_humidity = []
date_four_time_four_wind_speed = []
date_four_time_four_wind_direction = []

# define day_four_time_five arrays
date_four_time_five = []
date_four_time_five_temp = []
date_four_time_five_temp_min = []
date_four_time_five_temp_max =[]
date_four_time_five_pressure = []
date_four_time_five_sea_level = []
date_four_time_five_grnd_level = []
date_four_time_five_humidity = []
date_four_time_five_wind_speed = []
date_four_time_five_wind_direction = []

# define day_four_time_six arrays
date_four_time_six = []
date_four_time_six_temp = []
date_four_time_six_temp_min = []
date_four_time_six_temp_max =[]
date_four_time_six_pressure = []
date_four_time_six_sea_level = []
date_four_time_six_grnd_level = []
date_four_time_six_humidity = []
date_four_time_six_wind_speed = []
date_four_time_six_wind_direction = []

# define day_four_time_seven arrays
date_four_time_seven = []
date_four_time_seven_temp = []
date_four_time_seven_temp_min = []
date_four_time_seven_temp_max =[]
date_four_time_seven_pressure = []
date_four_time_seven_sea_level = []
date_four_time_seven_grnd_level = []
date_four_time_seven_humidity = []
date_four_time_seven_wind_speed = []
date_four_time_seven_wind_direction = []


# define day_four_time_eight arrays
date_four_time_eight = []
date_four_time_eight_temp = []
date_four_time_eight_temp_min = []
date_four_time_eight_temp_max =[]
date_four_time_eight_pressure = []
date_four_time_eight_sea_level = []
date_four_time_eight_grnd_level = []
date_four_time_eight_humidity = []
date_four_time_eight_wind_speed = []
date_four_time_eight_wind_direction = []


# define day_five_time_one arrays
date_five_time_one = []
date_five_time_one_temp = []
date_five_time_one_temp_min = []
date_five_time_one_temp_max =[]
date_five_time_one_pressure = []
date_five_time_one_sea_level = []
date_five_time_one_grnd_level = []
date_five_time_one_humidity = []
date_five_time_one_wind_speed = []
date_five_time_one_wind_direction = []

# define day_five_time_two arrays
date_five_time_two = []
date_five_time_two_temp = []
date_five_time_two_temp_min = []
date_five_time_two_temp_max =[]
date_five_time_two_pressure = []
date_five_time_two_sea_level = []
date_five_time_two_grnd_level = []
date_five_time_two_humidity = []
date_five_time_two_wind_speed = []
date_five_time_two_wind_direction = []


# define day_five_time_three arrays
date_five_time_three = []
date_five_time_three_temp = []
date_five_time_three_temp_min = []
date_five_time_three_temp_max =[]
date_five_time_three_pressure = []
date_five_time_three_sea_level = []
date_five_time_three_grnd_level = []
date_five_time_three_humidity = []
date_five_time_three_wind_speed = []
date_five_time_three_wind_direction = []

# define day_five_time_four arrays
date_five_time_four = []
date_five_time_four_temp = []
date_five_time_four_temp_min = []
date_five_time_four_temp_max =[]
date_five_time_four_pressure = []
date_five_time_four_sea_level = []
date_five_time_four_grnd_level = []
date_five_time_four_humidity = []
date_five_time_four_wind_speed = []
date_five_time_four_wind_direction = []

# define day_five_time_five arrays
date_five_time_five = []
date_five_time_five_temp = []
date_five_time_five_temp_min = []
date_five_time_five_temp_max =[]
date_five_time_five_pressure = []
date_five_time_five_sea_level = []
date_five_time_five_grnd_level = []
date_five_time_five_humidity = []
date_five_time_five_wind_speed = []
date_five_time_five_wind_direction = []

# define day_five_time_six arrays
date_five_time_six = []
date_five_time_six_temp = []
date_five_time_six_temp_min = []
date_five_time_six_temp_max =[]
date_five_time_six_pressure = []
date_five_time_six_sea_level = []
date_five_time_six_grnd_level = []
date_five_time_six_humidity = []
date_five_time_six_wind_speed = []
date_five_time_six_wind_direction = []


# define day_five_time_seven arrays
date_five_time_seven = []
date_five_time_seven_temp = []
date_five_time_seven_temp_min = []
date_five_time_seven_temp_max =[]
date_five_time_seven_pressure = []
date_five_time_seven_sea_level = []
date_five_time_seven_grnd_level = []
date_five_time_seven_humidity = []
date_five_time_seven_wind_speed = []
date_five_time_seven_wind_direction = []


# define day_five_time_eight arrays
date_five_time_eight = []
date_five_time_eight_temp = []
date_five_time_eight_temp_min = []
date_five_time_eight_temp_max =[]
date_five_time_eight_pressure = []
date_five_time_eight_sea_level = []
date_five_time_eight_grnd_level = []
date_five_time_eight_humidity = []
date_five_time_eight_wind_speed = []
date_five_time_eight_wind_direction = []

# %%
# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()

    #print(response)
    try:
        city_id.append(response['city']['id'])
        city_name.append(response['city']['name'])
        city_lat.append(response['city']['coord']['lat'])
        city_lon.append(response['city']['coord']['lon'])
        country.append(response['city']['country'])
        city_time.append(response['city']['timezone'])
        
        # get the date_one data
        
        date_one_time_one.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][0]['dt'])))
        date_one_time_one_temp.append(response['list'][0]['main']['temp'])
        date_one_time_one_temp_min.append(response['list'][0]['main']['temp_min'])
        date_one_time_one_temp_max.append(response['list'][0]['main']['temp_max'])
        date_one_time_one_pressure.append(response['list'][0]['main']['pressure'])
        date_one_time_one_sea_level.append(response['list'][0]['main']['sea_level'])
        date_one_time_one_grnd_level.append(response['list'][0]['main']['grnd_level'])
        date_one_time_one_humidity.append(response['list'][0]['main']['humidity'])
        date_one_time_one_wind_speed.append(response['list'][0]['wind']['speed'])
        date_one_time_one_wind_direction.append(response['list'][0]['wind']['deg'])
     
        date_one_time_two.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][1]['dt'])))
        date_one_time_two_temp.append(response['list'][1]['main']['temp'])
        date_one_time_two_temp_min.append(response['list'][1]['main']['temp_min'])
        date_one_time_two_temp_max.append(response['list'][1]['main']['temp_max'])
        date_one_time_two_pressure.append(response['list'][1]['main']['pressure'])
        date_one_time_two_sea_level.append(response['list'][1]['main']['sea_level'])
        date_one_time_two_grnd_level.append(response['list'][1]['main']['grnd_level'])
        date_one_time_two_humidity.append(response['list'][1]['main']['humidity'])
        date_one_time_two_wind_speed.append(response['list'][1]['wind']['speed'])
        date_one_time_two_wind_direction.append(response['list'][1]['wind']['deg'])

        date_one_time_three.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][2]['dt'])))
        date_one_time_three_temp.append(response['list'][2]['main']['temp'])
        date_one_time_three_temp_min.append(response['list'][2]['main']['temp_min'])
        date_one_time_three_temp_max.append(response['list'][2]['main']['temp_max'])
        date_one_time_three_pressure.append(response['list'][2]['main']['pressure'])
        date_one_time_three_sea_level.append(response['list'][2]['main']['sea_level'])
        date_one_time_three_grnd_level.append(response['list'][2]['main']['grnd_level'])
        date_one_time_three_humidity.append(response['list'][2]['main']['humidity'])
        date_one_time_three_wind_speed.append(response['list'][2]['wind']['speed'])
        date_one_time_three_wind_direction.append(response['list'][2]['wind']['deg'])


        date_one_time_four.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][3]['dt'])))
        date_one_time_four_temp.append(response['list'][3]['main']['temp'])
        date_one_time_four_temp_min.append(response['list'][3]['main']['temp_min'])
        date_one_time_four_temp_max.append(response['list'][3]['main']['temp_max'])
        date_one_time_four_pressure.append(response['list'][3]['main']['pressure'])
        date_one_time_four_sea_level.append(response['list'][3]['main']['sea_level'])
        date_one_time_four_grnd_level.append(response['list'][3]['main']['grnd_level'])
        date_one_time_four_humidity.append(response['list'][3]['main']['humidity'])
        date_one_time_four_wind_speed.append(response['list'][3]['wind']['speed'])
        date_one_time_four_wind_direction.append(response['list'][3]['wind']['deg'])

        date_one_time_five.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][4]['dt'])))
        date_one_time_five_temp.append(response['list'][4]['main']['temp'])
        date_one_time_five_temp_min.append(response['list'][4]['main']['temp_min'])
        date_one_time_five_temp_max.append(response['list'][4]['main']['temp_max'])
        date_one_time_five_pressure.append(response['list'][4]['main']['pressure'])
        date_one_time_five_sea_level.append(response['list'][4]['main']['sea_level'])
        date_one_time_five_grnd_level.append(response['list'][4]['main']['grnd_level'])
        date_one_time_five_humidity.append(response['list'][4]['main']['humidity'])
        date_one_time_five_wind_speed.append(response['list'][4]['wind']['speed'])
        date_one_time_five_wind_direction.append(response['list'][4]['wind']['deg'])

        date_one_time_six.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][5]['dt'])))
        date_one_time_six_temp.append(response['list'][5]['main']['temp'])
        date_one_time_six_temp_min.append(response['list'][5]['main']['temp_min'])
        date_one_time_six_temp_max.append(response['list'][5]['main']['temp_max'])
        date_one_time_six_pressure.append(response['list'][5]['main']['pressure'])
        date_one_time_six_sea_level.append(response['list'][5]['main']['sea_level'])
        date_one_time_six_grnd_level.append(response['list'][5]['main']['grnd_level'])
        date_one_time_six_humidity.append(response['list'][5]['main']['humidity'])
        date_one_time_six_wind_speed.append(response['list'][5]['wind']['speed'])
        date_one_time_six_wind_direction.append(response['list'][5]['wind']['deg'])
        
        date_one_time_seven.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][6]['dt'])))
        date_one_time_seven_temp.append(response['list'][6]['main']['temp'])
        date_one_time_seven_temp_min.append(response['list'][6]['main']['temp_min'])
        date_one_time_seven_temp_max.append(response['list'][6]['main']['temp_max'])
        date_one_time_seven_pressure.append(response['list'][6]['main']['pressure'])
        date_one_time_seven_sea_level.append(response['list'][6]['main']['sea_level'])
        date_one_time_seven_grnd_level.append(response['list'][6]['main']['grnd_level'])
        date_one_time_seven_humidity.append(response['list'][6]['main']['humidity'])
        date_one_time_seven_wind_speed.append(response['list'][6]['wind']['speed'])
        date_one_time_seven_wind_direction.append(response['list'][6]['wind']['deg'])
        
        date_one_time_eight.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][7]['dt'])))
        date_one_time_eight_temp.append(response['list'][7]['main']['temp'])
        date_one_time_eight_temp_min.append(response['list'][7]['main']['temp_min'])
        date_one_time_eight_temp_max.append(response['list'][7]['main']['temp_max'])
        date_one_time_eight_pressure.append(response['list'][7]['main']['pressure'])
        date_one_time_eight_sea_level.append(response['list'][7]['main']['sea_level'])
        date_one_time_eight_grnd_level.append(response['list'][7]['main']['grnd_level'])
        date_one_time_eight_humidity.append(response['list'][7]['main']['humidity'])
        date_one_time_eight_wind_speed.append(response['list'][7]['wind']['speed'])
        date_one_time_eight_wind_direction.append(response['list'][7]['wind']['deg'])


        
        
        
        

          # get the date_two data
        
        date_two_time_one.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][8]['dt'])))
        date_two_time_one_temp.append(response['list'][8]['main']['temp'])
        date_two_time_one_temp_min.append(response['list'][8]['main']['temp_min'])
        date_two_time_one_temp_max.append(response['list'][8]['main']['temp_max'])
        date_two_time_one_pressure.append(response['list'][8]['main']['pressure'])
        date_two_time_one_sea_level.append(response['list'][8]['main']['sea_level'])
        date_two_time_one_grnd_level.append(response['list'][8]['main']['grnd_level'])
        date_two_time_one_humidity.append(response['list'][8]['main']['humidity'])
        date_two_time_one_wind_speed.append(response['list'][8]['wind']['speed'])
        date_two_time_one_wind_direction.append(response['list'][8]['wind']['deg'])
     
        date_two_time_two.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][9]['dt'])))
        date_two_time_two_temp.append(response['list'][9]['main']['temp'])
        date_two_time_two_temp_min.append(response['list'][9]['main']['temp_min'])
        date_two_time_two_temp_max.append(response['list'][9]['main']['temp_max'])
        date_two_time_two_pressure.append(response['list'][9]['main']['pressure'])
        date_two_time_two_sea_level.append(response['list'][9]['main']['sea_level'])
        date_two_time_two_grnd_level.append(response['list'][9]['main']['grnd_level'])
        date_two_time_two_humidity.append(response['list'][9]['main']['humidity'])
        date_two_time_two_wind_speed.append(response['list'][9]['wind']['speed'])
        date_two_time_two_wind_direction.append(response['list'][9]['wind']['deg'])

        date_two_time_three.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][10]['dt'])))
        date_two_time_three_temp.append(response['list'][10]['main']['temp'])
        date_two_time_three_temp_min.append(response['list'][10]['main']['temp_min'])
        date_two_time_three_temp_max.append(response['list'][10]['main']['temp_max'])
        date_two_time_three_pressure.append(response['list'][10]['main']['pressure'])
        date_two_time_three_sea_level.append(response['list'][10]['main']['sea_level'])
        date_two_time_three_grnd_level.append(response['list'][10]['main']['grnd_level'])
        date_two_time_three_humidity.append(response['list'][10]['main']['humidity'])
        date_two_time_three_wind_speed.append(response['list'][10]['wind']['speed'])
        date_two_time_three_wind_direction.append(response['list'][10]['wind']['deg'])


        date_two_time_four.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][11]['dt'])))
        date_two_time_four_temp.append(response['list'][11]['main']['temp'])
        date_two_time_four_temp_min.append(response['list'][11]['main']['temp_min'])
        date_two_time_four_temp_max.append(response['list'][11]['main']['temp_max'])
        date_two_time_four_pressure.append(response['list'][11]['main']['pressure'])
        date_two_time_four_sea_level.append(response['list'][11]['main']['sea_level'])
        date_two_time_four_grnd_level.append(response['list'][11]['main']['grnd_level'])
        date_two_time_four_humidity.append(response['list'][11]['main']['humidity'])
        date_two_time_four_wind_speed.append(response['list'][11]['wind']['speed'])
        date_two_time_four_wind_direction.append(response['list'][11]['wind']['deg'])

        date_two_time_five.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][12]['dt'])))
        date_two_time_five_temp.append(response['list'][12]['main']['temp'])
        date_two_time_five_temp_min.append(response['list'][12]['main']['temp_min'])
        date_two_time_five_temp_max.append(response['list'][12]['main']['temp_max'])
        date_two_time_five_pressure.append(response['list'][12]['main']['pressure'])
        date_two_time_five_sea_level.append(response['list'][12]['main']['sea_level'])
        date_two_time_five_grnd_level.append(response['list'][12]['main']['grnd_level'])
        date_two_time_five_humidity.append(response['list'][12]['main']['humidity'])
        date_two_time_five_wind_speed.append(response['list'][12]['wind']['speed'])
        date_two_time_five_wind_direction.append(response['list'][12]['wind']['deg'])

        date_two_time_six.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][13]['dt'])))
        date_two_time_six_temp.append(response['list'][13]['main']['temp'])
        date_two_time_six_temp_min.append(response['list'][13]['main']['temp_min'])
        date_two_time_six_temp_max.append(response['list'][13]['main']['temp_max'])
        date_two_time_six_pressure.append(response['list'][13]['main']['pressure'])
        date_two_time_six_sea_level.append(response['list'][13]['main']['sea_level'])
        date_two_time_six_grnd_level.append(response['list'][13]['main']['grnd_level'])
        date_two_time_six_humidity.append(response['list'][13]['main']['humidity'])
        date_two_time_six_wind_speed.append(response['list'][13]['wind']['speed'])
        date_two_time_six_wind_direction.append(response['list'][13]['wind']['deg'])
        
        date_two_time_seven.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][14]['dt'])))
        date_two_time_seven_temp.append(response['list'][14]['main']['temp'])
        date_two_time_seven_temp_min.append(response['list'][14]['main']['temp_min'])
        date_two_time_seven_temp_max.append(response['list'][14]['main']['temp_max'])
        date_two_time_seven_pressure.append(response['list'][14]['main']['pressure'])
        date_two_time_seven_sea_level.append(response['list'][14]['main']['sea_level'])
        date_two_time_seven_grnd_level.append(response['list'][14]['main']['grnd_level'])
        date_two_time_seven_humidity.append(response['list'][14]['main']['humidity'])
        date_two_time_seven_wind_speed.append(response['list'][14]['wind']['speed'])
        date_two_time_seven_wind_direction.append(response['list'][14]['wind']['deg'])
        
        
        date_two_time_eight.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][15]['dt'])))
        date_two_time_eight_temp.append(response['list'][15]['main']['temp'])
        date_two_time_eight_temp_min.append(response['list'][15]['main']['temp_min'])
        date_two_time_eight_temp_max.append(response['list'][15]['main']['temp_max'])
        date_two_time_eight_pressure.append(response['list'][15]['main']['pressure'])
        date_two_time_eight_sea_level.append(response['list'][15]['main']['sea_level'])
        date_two_time_eight_grnd_level.append(response['list'][15]['main']['grnd_level'])
        date_two_time_eight_humidity.append(response['list'][15]['main']['humidity'])
        date_two_time_eight_wind_speed.append(response['list'][15]['wind']['speed'])
        date_two_time_eight_wind_direction.append(response['list'][15]['wind']['deg'])
        
        # get the date_three data
        
        date_three_time_one.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][16]['dt'])))
        date_three_time_one_temp.append(response['list'][16]['main']['temp'])
        date_three_time_one_temp_min.append(response['list'][16]['main']['temp_min'])
        date_three_time_one_temp_max.append(response['list'][16]['main']['temp_max'])
        date_three_time_one_pressure.append(response['list'][16]['main']['pressure'])
        date_three_time_one_sea_level.append(response['list'][16]['main']['sea_level'])
        date_three_time_one_grnd_level.append(response['list'][16]['main']['grnd_level'])
        date_three_time_one_humidity.append(response['list'][16]['main']['humidity'])
        date_three_time_one_wind_speed.append(response['list'][16]['wind']['speed'])
        date_three_time_one_wind_direction.append(response['list'][16]['wind']['deg'])
     
        date_three_time_two.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][17]['dt'])))
        date_three_time_two_temp.append(response['list'][17]['main']['temp'])
        date_three_time_two_temp_min.append(response['list'][17]['main']['temp_min'])
        date_three_time_two_temp_max.append(response['list'][17]['main']['temp_max'])
        date_three_time_two_pressure.append(response['list'][17]['main']['pressure'])
        date_three_time_two_sea_level.append(response['list'][17]['main']['sea_level'])
        date_three_time_two_grnd_level.append(response['list'][17]['main']['grnd_level'])
        date_three_time_two_humidity.append(response['list'][17]['main']['humidity'])
        date_three_time_two_wind_speed.append(response['list'][17]['wind']['speed'])
        date_three_time_two_wind_direction.append(response['list'][122]['wind']['deg'])

        date_three_time_three.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][18]['dt'])))
        date_three_time_three_temp.append(response['list'][18]['main']['temp'])
        date_three_time_three_temp_min.append(response['list'][18]['main']['temp_min'])
        date_three_time_three_temp_max.append(response['list'][18]['main']['temp_max'])
        date_three_time_three_pressure.append(response['list'][18]['main']['pressure'])
        date_three_time_three_sea_level.append(response['list'][18]['main']['sea_level'])
        date_three_time_three_grnd_level.append(response['list'][18]['main']['grnd_level'])
        date_three_time_three_humidity.append(response['list'][18]['main']['humidity'])
        date_three_time_three_wind_speed.append(response['list'][18]['wind']['speed'])
        date_three_time_three_wind_direction.append(response['list'][18]['wind']['deg'])


        date_three_time_four.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][19]['dt'])))
        date_three_time_four_temp.append(response['list'][19]['main']['temp'])
        date_three_time_four_temp_min.append(response['list'][19]['main']['temp_min'])
        date_three_time_four_temp_max.append(response['list'][19]['main']['temp_max'])
        date_three_time_four_pressure.append(response['list'][19]['main']['pressure'])
        date_three_time_four_sea_level.append(response['list'][19]['main']['sea_level'])
        date_three_time_four_grnd_level.append(response['list'][19]['main']['grnd_level'])
        date_three_time_four_humidity.append(response['list'][19]['main']['humidity'])
        date_three_time_four_wind_speed.append(response['list'][19]['wind']['speed'])
        date_three_time_four_wind_direction.append(response['list'][19]['wind']['deg']) 


        date_three_time_five.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][20]['dt'])))
        date_three_time_five_temp.append(response['list'][20]['main']['temp'])
        date_three_time_five_temp_min.append(response['list'][20]['main']['temp_min'])
        date_three_time_five_temp_max.append(response['list'][20]['main']['temp_max'])
        date_three_time_five_pressure.append(response['list'][20]['main']['pressure'])
        date_three_time_five_sea_level.append(response['list'][20]['main']['sea_level'])
        date_three_time_five_grnd_level.append(response['list'][20]['main']['grnd_level'])
        date_three_time_five_humidity.append(response['list'][20]['main']['humidity'])
        date_three_time_five_wind_speed.append(response['list'][20]['wind']['speed'])
        date_three_time_five_wind_direction.append(response['list'][20]['wind']['deg'])


        date_three_time_six.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][22]['dt'])))
        date_three_time_six_temp.append(response['list'][22]['main']['temp'])
        date_three_time_six_temp_min.append(response['list'][22]['main']['temp_min'])
        date_three_time_six_temp_max.append(response['list'][22]['main']['temp_max'])
        date_three_time_six_pressure.append(response['list'][22]['main']['pressure'])
        date_three_time_six_sea_level.append(response['list'][22]['main']['sea_level'])
        date_three_time_six_grnd_level.append(response['list'][22]['main']['grnd_level'])
        date_three_time_six_humidity.append(response['list'][22]['main']['humidity'])
        date_three_time_six_wind_speed.append(response['list'][22]['wind']['speed'])
        date_three_time_six_wind_direction.append(response['list'][22]['wind']['deg'])

        
        date_three_time_seven.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][23]['dt'])))
        date_three_time_seven_temp.append(response['list'][23]['main']['temp'])
        date_three_time_seven_temp_min.append(response['list'][23]['main']['temp_min'])
        date_three_time_seven_temp_max.append(response['list'][23]['main']['temp_max'])
        date_three_time_seven_pressure.append(response['list'][23]['main']['pressure'])
        date_three_time_seven_sea_level.append(response['list'][23]['main']['sea_level'])
        date_three_time_seven_grnd_level.append(response['list'][23]['main']['grnd_level'])
        date_three_time_seven_humidity.append(response['list'][23]['main']['humidity'])
        date_three_time_seven_wind_speed.append(response['list'][23]['wind']['speed'])
        date_three_time_seven_wind_direction.append(response['list'][23]['wind']['deg'])
        
        
        date_three_time_eight.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][24]['dt'])))
        date_three_time_eight_temp.append(response['list'][24]['main']['temp'])
        date_three_time_eight_temp_min.append(response['list'][24]['main']['temp_min'])
        date_three_time_eight_temp_max.append(response['list'][24]['main']['temp_max'])
        date_three_time_eight_pressure.append(response['list'][24]['main']['pressure'])
        date_three_time_eight_sea_level.append(response['list'][24]['main']['sea_level'])
        date_three_time_eight_grnd_level.append(response['list'][24]['main']['grnd_level'])
        date_three_time_eight_humidity.append(response['list'][24]['main']['humidity'])
        date_three_time_eight_wind_speed.append(response['list'][24]['wind']['speed'])
        date_three_time_eight_wind_direction.append(response['list'][24]['wind']['deg'])


        
        
        
        
        
        
        

        
         # get the date_four data
        
        date_four_time_one.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][25]['dt'])))
        date_four_time_one_temp.append(response['list'][25]['main']['temp'])
        date_four_time_one_temp_min.append(response['list'][25]['main']['temp_min'])
        date_four_time_one_temp_max.append(response['list'][25]['main']['temp_max'])
        date_four_time_one_pressure.append(response['list'][25]['main']['pressure'])
        date_four_time_one_sea_level.append(response['list'][25]['main']['sea_level'])
        date_four_time_one_grnd_level.append(response['list'][25]['main']['grnd_level'])
        date_four_time_one_humidity.append(response['list'][25]['main']['humidity'])
        date_four_time_one_wind_speed.append(response['list'][25]['wind']['speed'])
        date_four_time_one_wind_direction.append(response['list'][25]['wind']['deg'])
     
        date_four_time_two.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][26]['dt'])))
        date_four_time_two_temp.append(response['list'][26]['main']['temp'])
        date_four_time_two_temp_min.append(response['list'][26]['main']['temp_min'])
        date_four_time_two_temp_max.append(response['list'][26]['main']['temp_max'])
        date_four_time_two_pressure.append(response['list'][26]['main']['pressure'])
        date_four_time_two_sea_level.append(response['list'][26]['main']['sea_level'])
        date_four_time_two_grnd_level.append(response['list'][26]['main']['grnd_level'])
        date_four_time_two_humidity.append(response['list'][26]['main']['humidity'])
        date_four_time_two_wind_speed.append(response['list'][26]['wind']['speed'])
        date_four_time_two_wind_direction.append(response['list'][26]['wind']['deg'])


        date_four_time_three.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][27]['dt'])))
        date_four_time_three_temp.append(response['list'][27]['main']['temp'])
        date_four_time_three_temp_min.append(response['list'][27]['main']['temp_min'])
        date_four_time_three_temp_max.append(response['list'][27]['main']['temp_max'])
        date_four_time_three_pressure.append(response['list'][27]['main']['pressure'])
        date_four_time_three_sea_level.append(response['list'][27]['main']['sea_level'])
        date_four_time_three_grnd_level.append(response['list'][27]['main']['grnd_level'])
        date_four_time_three_humidity.append(response['list'][27]['main']['humidity'])
        date_four_time_three_wind_speed.append(response['list'][27]['wind']['speed'])
        date_four_time_three_wind_direction.append(response['list'][27]['wind']['deg'])


        date_four_time_four.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][28]['dt'])))
        date_four_time_four_temp.append(response['list'][28]['main']['temp'])
        date_four_time_four_temp_min.append(response['list'][28]['main']['temp_min'])
        date_four_time_four_temp_max.append(response['list'][28]['main']['temp_max'])
        date_four_time_four_pressure.append(response['list'][28]['main']['pressure'])
        date_four_time_four_sea_level.append(response['list'][28]['main']['sea_level'])
        date_four_time_four_grnd_level.append(response['list'][28]['main']['grnd_level'])
        date_four_time_four_humidity.append(response['list'][28]['main']['humidity'])
        date_four_time_four_wind_speed.append(response['list'][28]['wind']['speed'])
        date_four_time_four_wind_direction.append(response['list'][28]['wind']['deg'])

        date_four_time_five.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][29]['dt'])))
        date_four_time_five_temp.append(response['list'][29]['main']['temp'])
        date_four_time_five_temp_min.append(response['list'][29]['main']['temp_min'])
        date_four_time_five_temp_max.append(response['list'][29]['main']['temp_max'])
        date_four_time_five_pressure.append(response['list'][29]['main']['pressure'])
        date_four_time_five_sea_level.append(response['list'][29]['main']['sea_level'])
        date_four_time_five_grnd_level.append(response['list'][29]['main']['grnd_level'])
        date_four_time_five_humidity.append(response['list'][29]['main']['humidity'])
        date_four_time_five_wind_speed.append(response['list'][29]['wind']['speed'])
        date_four_time_five_wind_direction.append(response['list'][29]['wind']['deg'])

        date_four_time_six.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][30]['dt'])))
        date_four_time_six_temp.append(response['list'][30]['main']['temp'])
        date_four_time_six_temp_min.append(response['list'][30]['main']['temp_min'])
        date_four_time_six_temp_max.append(response['list'][30]['main']['temp_max'])
        date_four_time_six_pressure.append(response['list'][30]['main']['pressure'])
        date_four_time_six_sea_level.append(response['list'][30]['main']['sea_level'])
        date_four_time_six_grnd_level.append(response['list'][30]['main']['grnd_level'])
        date_four_time_six_humidity.append(response['list'][30]['main']['humidity'])
        date_four_time_six_wind_speed.append(response['list'][30]['wind']['speed'])
        date_four_time_six_wind_direction.append(response['list'][30]['wind']['deg'])
        
        
        date_four_time_seven.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][31]['dt'])))
        date_four_time_seven_temp.append(response['list'][31]['main']['temp'])
        date_four_time_seven_temp_min.append(response['list'][31]['main']['temp_min'])
        date_four_time_seven_temp_max.append(response['list'][31]['main']['temp_max'])
        date_four_time_seven_pressure.append(response['list'][31]['main']['pressure'])
        date_four_time_seven_sea_level.append(response['list'][31]['main']['sea_level'])
        date_four_time_seven_grnd_level.append(response['list'][31]['main']['grnd_level'])
        date_four_time_seven_humidity.append(response['list'][31]['main']['humidity'])
        date_four_time_seven_wind_speed.append(response['list'][31]['wind']['speed'])
        date_four_time_seven_wind_direction.append(response['list'][31]['wind']['deg'])

        date_four_time_eight.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][32]['dt'])))
        date_four_time_eight_temp.append(response['list'][32]['main']['temp'])
        date_four_time_eight_temp_min.append(response['list'][32]['main']['temp_min'])
        date_four_time_eight_temp_max.append(response['list'][32]['main']['temp_max'])
        date_four_time_eight_pressure.append(response['list'][32]['main']['pressure'])
        date_four_time_eight_sea_level.append(response['list'][32]['main']['sea_level'])
        date_four_time_eight_grnd_level.append(response['list'][32]['main']['grnd_level'])
        date_four_time_eight_humidity.append(response['list'][32]['main']['humidity'])
        date_four_time_eight_wind_speed.append(response['list'][32]['wind']['speed'])
        date_four_time_eight_wind_direction.append(response['list'][32]['wind']['deg'])

        
        

          # get the date_five data
        
        
          # get the date_five data
        
        date_five_time_one.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][33]['dt'])))
        date_five_time_one_temp.append(response['list'][33]['main']['temp'])
        date_five_time_one_temp_min.append(response['list'][33]['main']['temp_min'])
        date_five_time_one_temp_max.append(response['list'][33]['main']['temp_max'])
        date_five_time_one_pressure.append(response['list'][33]['main']['pressure'])
        date_five_time_one_sea_level.append(response['list'][33]['main']['sea_level'])
        date_five_time_one_grnd_level.append(response['list'][33]['main']['grnd_level'])
        date_five_time_one_humidity.append(response['list'][33]['main']['humidity'])
        date_five_time_one_wind_speed.append(response['list'][33]['wind']['speed'])
        date_five_time_one_wind_direction.append(response['list'][33]['wind']['deg'])
     
        date_five_time_two.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][34]['dt'])))
        date_five_time_two_temp.append(response['list'][34]['main']['temp'])
        date_five_time_two_temp_min.append(response['list'][34]['main']['temp_min'])
        date_five_time_two_temp_max.append(response['list'][34]['main']['temp_max'])
        date_five_time_two_pressure.append(response['list'][34]['main']['pressure'])
        date_five_time_two_sea_level.append(response['list'][34]['main']['sea_level'])
        date_five_time_two_grnd_level.append(response['list'][34]['main']['grnd_level'])
        date_five_time_two_humidity.append(response['list'][34]['main']['humidity'])
        date_five_time_two_wind_speed.append(response['list'][34]['wind']['speed'])
        date_five_time_two_wind_direction.append(response['list'][34]['wind']['deg'])

        date_five_time_three.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][35]['dt'])))
        date_five_time_three_temp.append(response['list'][35]['main']['temp'])
        date_five_time_three_temp_min.append(response['list'][35]['main']['temp_min'])
        date_five_time_three_temp_max.append(response['list'][35]['main']['temp_max'])
        date_five_time_three_pressure.append(response['list'][35]['main']['pressure'])
        date_five_time_three_sea_level.append(response['list'][35]['main']['sea_level'])
        date_five_time_three_grnd_level.append(response['list'][35]['main']['grnd_level'])
        date_five_time_three_humidity.append(response['list'][35]['main']['humidity'])
        date_five_time_three_wind_speed.append(response['list'][35]['wind']['speed'])
        date_five_time_three_wind_direction.append(response['list'][35]['wind']['deg'])

        date_five_time_four.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][36]['dt'])))
        date_five_time_four_temp.append(response['list'][36]['main']['temp'])
        date_five_time_four_temp_min.append(response['list'][36]['main']['temp_min'])
        date_five_time_four_temp_max.append(response['list'][36]['main']['temp_max'])
        date_five_time_four_pressure.append(response['list'][36]['main']['pressure'])
        date_five_time_four_sea_level.append(response['list'][36]['main']['sea_level'])
        date_five_time_four_grnd_level.append(response['list'][36]['main']['grnd_level'])
        date_five_time_four_humidity.append(response['list'][36]['main']['humidity'])
        date_five_time_four_wind_speed.append(response['list'][36]['wind']['speed'])
        date_five_time_four_wind_direction.append(response['list'][36]['wind']['deg'])

        date_five_time_five.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][37]['dt'])))
        date_five_time_five_temp.append(response['list'][37]['main']['temp'])
        date_five_time_five_temp_min.append(response['list'][37]['main']['temp_min'])
        date_five_time_five_temp_max.append(response['list'][37]['main']['temp_max'])
        date_five_time_five_pressure.append(response['list'][37]['main']['pressure'])
        date_five_time_five_sea_level.append(response['list'][37]['main']['sea_level'])
        date_five_time_five_grnd_level.append(response['list'][37]['main']['grnd_level'])
        date_five_time_five_humidity.append(response['list'][37]['main']['humidity'])
        date_five_time_five_wind_speed.append(response['list'][37]['wind']['speed'])
        date_five_time_five_wind_direction.append(response['list'][37]['wind']['deg'])


        date_five_time_six.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][38]['dt'])))
        date_five_time_six_temp.append(response['list'][38]['main']['temp'])
        date_five_time_six_temp_min.append(response['list'][38]['main']['temp_min'])
        date_five_time_six_temp_max.append(response['list'][38]['main']['temp_max'])
        date_five_time_six_pressure.append(response['list'][38]['main']['pressure'])
        date_five_time_six_sea_level.append(response['list'][38]['main']['sea_level'])
        date_five_time_six_grnd_level.append(response['list'][38]['main']['grnd_level'])
        date_five_time_six_humidity.append(response['list'][38]['main']['humidity'])
        date_five_time_six_wind_speed.append(response['list'][38]['wind']['speed'])
        date_five_time_six_wind_direction.append(response['list'][38]['wind']['deg'])
        
        date_five_time_seven.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][39]['dt'])))
        date_five_time_seven_temp.append(response['list'][39]['main']['temp'])
        date_five_time_seven_temp_min.append(response['list'][39]['main']['temp_min'])
        date_five_time_seven_temp_max.append(response['list'][39]['main']['temp_max'])
        date_five_time_seven_pressure.append(response['list'][39]['main']['pressure'])
        date_five_time_seven_sea_level.append(response['list'][39]['main']['sea_level'])
        date_five_time_seven_grnd_level.append(response['list'][39]['main']['grnd_level'])
        date_five_time_seven_humidity.append(response['list'][39]['main']['humidity'])
        date_five_time_seven_wind_speed.append(response['list'][39]['wind']['speed'])
        date_five_time_seven_wind_direction.append(response['list'][39]['wind']['deg'])
        
        
        date_five_time_eight.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(response['list'][40]['dt'])))
        date_five_time_eight_temp.append(response['list'][40]['main']['temp'])
        date_five_time_eight_temp_min.append(response['list'][40]['main']['temp_min'])
        date_five_time_eight_temp_max.append(response['list'][40]['main']['temp_max'])
        date_five_time_eight_pressure.append(response['list'][40]['main']['pressure'])
        date_five_time_eight_sea_level.append(response['list'][40]['main']['sea_level'])
        date_five_time_eight_grnd_level.append(response['list'][40]['main']['grnd_level'])
        date_five_time_eight_humidity.append(response['list'][40]['main']['humidity'])
        date_five_time_eight_wind_speed.append(response['list'][40]['wind']['speed'])
        date_five_time_eight_wind_direction.append(response['list'][40]['wind']['deg'])



    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# Missing field/result... skipping.

# %%
print("# citites found in API data: ", len(city_name))
# Out:
# # citites found in API data:  1

# %%
print(city_name)
# Out:
# ['Quito']

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    'city_id': city_id,
    'city_name': city_name,
    'city_lat': city_lat,
    'city_lon': city_lon,
    'country': country,
    'city_time': city_time,
    'date_one_time_one': date_one_time_one,
    'date_one_time_one_temp': date_one_time_one_temp,
    'date_one_time_one_temp_min': date_one_time_one_temp_min,
    'date_one_time_one_temp_max': date_one_time_one_temp_max,
    'date_one_time_one_pressure': date_one_time_one_pressure,
    'date_one_time_one_sea_level': date_one_time_one_sea_level,
    'date_one_time_one_grnd_level': date_one_time_one_grnd_level,
    'date_one_time_one_humidity': date_one_time_one_humidity,
    'date_one_time_one_wind_speed': date_one_time_one_wind_speed,
    'date_one_time_one_direction': date_one_time_one_wind_direction,
    'date_one_time_two': date_one_time_two,
    'date_one_time_two_temp': date_one_time_two_temp,
    'date_one_time_two_temp_min': date_one_time_two_temp_min,
    'date_one_time_two_temp_max': date_one_time_two_temp_max,
    'date_one_time_two_pressure': date_one_time_two_pressure,
    'date_one_time_two_sea_level': date_one_time_two_sea_level,
    'date_one_time_two_grnd_level': date_one_time_two_grnd_level,
    'date_one_time_two_humidity': date_one_time_two_humidity,
    'date_one_time_two_wind_speed': date_one_time_two_wind_speed,
    'date_one_time_two_direction': date_one_time_two_wind_direction,
    'date_one_time_three': date_one_time_three,
    'date_one_time_three_temp': date_one_time_three_temp,
    'date_one_time_three_temp_min': date_one_time_three_temp_min,
    'date_one_time_three_temp_max': date_one_time_three_temp_max,
    'date_one_time_three_pressure': date_one_time_three_pressure,
    'date_one_time_three_sea_level': date_one_time_three_sea_level,
    'date_one_time_three_grnd_level': date_one_time_three_grnd_level,
    'date_one_time_three_humidity': date_one_time_three_humidity,
    'date_one_time_three_wind_speed': date_one_time_three_wind_speed,
    'date_one_time_three_direction': date_one_time_three_wind_direction,
    'date_one_time_four': date_one_time_four,
    'date_one_time_four_temp': date_one_time_four_temp,
    'date_one_time_four_temp_min': date_one_time_four_temp_min,
    'date_one_time_four_temp_max': date_one_time_four_temp_max,
    'date_one_time_four_pressure': date_one_time_four_pressure,
    'date_one_time_four_sea_level': date_one_time_four_sea_level,
    'date_one_time_four_grnd_level': date_one_time_four_grnd_level,
    'date_one_time_four_humidity': date_one_time_four_humidity,
    'date_one_time_four_wind_speed': date_one_time_four_wind_speed,
    'date_one_time_four_direction': date_one_time_four_wind_direction,
    'date_one_time_five': date_one_time_five,
    'date_one_time_five_temp': date_one_time_five_temp,
    'date_one_time_five_temp_min': date_one_time_five_temp_min,
    'date_one_time_five_temp_max': date_one_time_five_temp_max,
    'date_one_time_five_pressure': date_one_time_five_pressure,
    'date_one_time_five_sea_level': date_one_time_five_sea_level,
    'date_one_time_five_grnd_level': date_one_time_five_grnd_level,
    'date_one_time_five_humidity': date_one_time_five_humidity,
    'date_one_time_five_wind_speed': date_one_time_five_wind_speed,
    'date_one_time_five_direction': date_one_time_five_wind_direction,
    'date_one_time_six': date_one_time_six,
    'date_one_time_six_temp': date_one_time_six_temp,
    'date_one_time_six_temp_min': date_one_time_six_temp_min,
    'date_one_time_six_temp_max': date_one_time_six_temp_max,
    'date_one_time_six_pressure': date_one_time_six_pressure,
    'date_one_time_six_sea_level': date_one_time_six_sea_level,
    'date_one_time_six_grnd_level': date_one_time_six_grnd_level,
    'date_one_time_six_humidity': date_one_time_six_humidity,
    'date_one_time_six_wind_speed': date_one_time_six_wind_speed,
    'date_one_time_six_direction': date_one_time_six_wind_direction,
    'date_one_time_seven': date_one_time_seven,
    'date_one_time_seven_temp': date_one_time_seven_temp,
    'date_one_time_seven_temp_min': date_one_time_seven_temp_min,
    'date_one_time_seven_temp_max': date_one_time_seven_temp_max,
    'date_one_time_seven_pressure': date_one_time_seven_pressure,
    'date_one_time_seven_sea_level': date_one_time_seven_sea_level,
    'date_one_time_seven_grnd_level': date_one_time_seven_grnd_level,
    'date_one_time_seven_humidity': date_one_time_seven_humidity,
    'date_one_time_seven_wind_speed': date_one_time_seven_wind_speed,
    'date_one_time_seven_direction': date_one_time_seven_wind_direction,
    'date_one_time_eight': date_one_time_eight,
    'date_one_time_eight_temp': date_one_time_eight_temp,
    'date_one_time_eight_temp_min': date_one_time_eight_temp_min,
    'date_one_time_eight_temp_max': date_one_time_eight_temp_max,
    'date_one_time_eight_pressure': date_one_time_eight_pressure,
    'date_one_time_eight_sea_level': date_one_time_eight_sea_level,
    'date_one_time_eight_grnd_level': date_one_time_eight_grnd_level,
    'date_one_time_eight_humidity': date_one_time_eight_humidity,
    'date_one_time_eight_wind_speed': date_one_time_eight_wind_speed,
    'date_one_time_eight_direction': date_one_time_eight_wind_direction,
    'date_two_time_one': date_two_time_one,
    'date_two_time_one_temp': date_two_time_one_temp,
    'date_two_time_one_temp_min': date_two_time_one_temp_min,
    'date_two_time_one_temp_max': date_two_time_one_temp_max,
    'date_two_time_one_pressure': date_two_time_one_pressure,
    'date_two_time_one_sea_level': date_two_time_one_sea_level,
    'date_two_time_one_grnd_level': date_two_time_one_grnd_level,
    'date_two_time_one_humidity': date_two_time_one_humidity,
    'date_two_time_one_wind_speed': date_two_time_one_wind_speed,
    'date_two_time_one_direction': date_two_time_one_wind_direction,
    'date_two_time_two': date_two_time_two,
    'date_two_time_two_temp': date_two_time_two_temp,
    'date_two_time_two_temp_min': date_two_time_two_temp_min,
    'date_two_time_two_temp_max': date_two_time_two_temp_max,
    'date_two_time_two_pressure': date_two_time_two_pressure,
    'date_two_time_two_sea_level': date_two_time_two_sea_level,
    'date_two_time_two_grnd_level': date_two_time_two_grnd_level,
    'date_two_time_two_humidity': date_two_time_two_humidity,
    'date_two_time_two_wind_speed': date_two_time_two_wind_speed,
    'date_two_time_two_direction': date_two_time_two_wind_direction,
    'date_two_time_three': date_two_time_three,
    'date_two_time_three_temp': date_two_time_three_temp,
    'date_two_time_three_temp_min': date_two_time_three_temp_min,
    'date_two_time_three_temp_max': date_two_time_three_temp_max,
    'date_two_time_three_pressure': date_two_time_three_pressure,
    'date_two_time_three_sea_level': date_two_time_three_sea_level,
    'date_two_time_three_grnd_level': date_two_time_three_grnd_level,
    'date_two_time_three_humidity': date_two_time_three_humidity,
    'date_two_time_three_wind_speed': date_two_time_three_wind_speed,
    'date_two_time_three_direction': date_two_time_three_wind_direction,
    'date_two_time_four': date_two_time_four,
    'date_two_time_four_temp': date_two_time_four_temp,
    'date_two_time_four_temp_min': date_two_time_four_temp_min,
    'date_two_time_four_temp_max': date_two_time_four_temp_max,
    'date_two_time_four_pressure': date_two_time_four_pressure,
    'date_two_time_four_sea_level': date_two_time_four_sea_level,
    'date_two_time_four_grnd_level': date_two_time_four_grnd_level,
    'date_two_time_four_humidity': date_two_time_four_humidity,
    'date_two_time_four_wind_speed': date_two_time_four_wind_speed,
    'date_two_time_four_direction': date_two_time_four_wind_direction,
    'date_two_time_five': date_two_time_five,
    'date_two_time_five_temp': date_two_time_five_temp,
    'date_two_time_five_temp_min': date_two_time_five_temp_min,
    'date_two_time_five_temp_max': date_two_time_five_temp_max,
    'date_two_time_five_pressure': date_two_time_five_pressure,
    'date_two_time_five_sea_level': date_two_time_five_sea_level,
    'date_two_time_five_grnd_level': date_two_time_five_grnd_level,
    'date_two_time_five_humidity': date_two_time_five_humidity,
    'date_two_time_five_wind_speed': date_two_time_five_wind_speed,
    'date_two_time_five_direction': date_two_time_five_wind_direction,
    'date_two_time_six': date_two_time_six,
    'date_two_time_six_temp': date_two_time_six_temp,
    'date_two_time_six_temp_min': date_two_time_six_temp_min,
    'date_two_time_six_temp_max': date_two_time_six_temp_max,
    'date_two_time_six_pressure': date_two_time_six_pressure,
    'date_two_time_six_sea_level': date_two_time_six_sea_level,
    'date_two_time_six_grnd_level': date_two_time_six_grnd_level,
    'date_two_time_six_humidity': date_two_time_six_humidity,
    'date_two_time_six_wind_speed': date_two_time_six_wind_speed,
    'date_two_time_six_direction': date_two_time_six_wind_direction,
    'date_two_time_seven': date_two_time_seven,
    'date_two_time_seven_temp': date_two_time_seven_temp,
    'date_two_time_seven_temp_min': date_two_time_seven_temp_min,
    'date_two_time_seven_temp_max': date_two_time_seven_temp_max,
    'date_two_time_seven_pressure': date_two_time_seven_pressure,
    'date_two_time_seven_sea_level': date_two_time_seven_sea_level,
    'date_two_time_seven_grnd_level': date_two_time_seven_grnd_level,
    'date_two_time_seven_humidity': date_two_time_seven_humidity,
    'date_two_time_seven_wind_speed': date_two_time_seven_wind_speed,
    'date_two_time_seven_direction': date_two_time_seven_wind_direction,
    'date_two_time_eight': date_two_time_eight,
    'date_two_time_eight_temp': date_two_time_eight_temp,
    'date_two_time_eight_temp_min': date_two_time_eight_temp_min,
    'date_two_time_eight_temp_max': date_two_time_eight_temp_max,
    'date_two_time_eight_pressure': date_two_time_eight_pressure,
    'date_two_time_eight_sea_level': date_two_time_eight_sea_level,
    'date_two_time_eight_grnd_level': date_two_time_eight_grnd_level,
    'date_two_time_eight_humidity': date_two_time_eight_humidity,
    'date_two_time_eight_wind_speed': date_two_time_eight_wind_speed,
    'date_two_time_eight_direction': date_two_time_eight_wind_direction,
    'date_three_time_one': date_three_time_one,
    'date_three_time_one_temp': date_three_time_one_temp,
    'date_three_time_one_temp_min': date_three_time_one_temp_min,
    'date_three_time_one_temp_max': date_three_time_one_temp_max,
    'date_three_time_one_pressure': date_three_time_one_pressure,
    'date_three_time_one_sea_level': date_three_time_one_sea_level,
    'date_three_time_one_grnd_level': date_three_time_one_grnd_level,
    'date_three_time_one_humidity': date_three_time_one_humidity,
    'date_three_time_one_wind_speed': date_three_time_one_wind_speed,
    'date_three_time_one_direction': date_three_time_one_wind_direction,
    'date_three_time_two': date_three_time_two,
    'date_three_time_two_temp': date_three_time_two_temp,
    'date_three_time_two_temp_min': date_three_time_two_temp_min,
    'date_three_time_two_temp_max': date_three_time_two_temp_max,
    'date_three_time_two_pressure': date_three_time_two_pressure,
    'date_three_time_two_sea_level': date_three_time_two_sea_level,
    'date_three_time_two_grnd_level': date_three_time_two_grnd_level,
    'date_three_time_two_humidity': date_three_time_two_humidity,
    'date_three_time_two_wind_speed': date_three_time_two_wind_speed,
    'date_three_time_two_direction': date_three_time_two_wind_direction,
    'date_three_time_three': date_three_time_three,
    'date_three_time_three_temp': date_three_time_three_temp,
    'date_three_time_three_temp_min': date_three_time_three_temp_min,
    'date_three_time_three_temp_max': date_three_time_three_temp_max,
    'date_three_time_three_pressure': date_three_time_three_pressure,
    'date_three_time_three_sea_level': date_three_time_three_sea_level,
    'date_three_time_three_grnd_level': date_three_time_three_grnd_level,
    'date_three_time_three_humidity': date_three_time_three_humidity,
    'date_three_time_three_wind_speed': date_three_time_three_wind_speed,
    'date_three_time_three_direction': date_three_time_three_wind_direction,
    'date_three_time_four': date_three_time_four,
    'date_three_time_four_temp': date_three_time_four_temp,
    'date_three_time_four_temp_min': date_three_time_four_temp_min,
    'date_three_time_four_temp_max': date_three_time_four_temp_max,
    'date_three_time_four_pressure': date_three_time_four_pressure,
    'date_three_time_four_sea_level': date_three_time_four_sea_level,
    'date_three_time_four_grnd_level': date_three_time_four_grnd_level,
    'date_three_time_four_humidity': date_three_time_four_humidity,
    'date_three_time_four_wind_speed': date_three_time_four_wind_speed,
    'date_three_time_four_direction': date_three_time_four_wind_direction,
    'date_three_time_five': date_three_time_five,
    'date_three_time_five_temp': date_three_time_five_temp,
    'date_three_time_five_temp_min': date_three_time_five_temp_min,
    'date_three_time_five_temp_max': date_three_time_five_temp_max,
    'date_three_time_five_pressure': date_three_time_five_pressure,
    'date_three_time_five_sea_level': date_three_time_five_sea_level,
    'date_three_time_five_grnd_level': date_three_time_five_grnd_level,
    'date_three_time_five_humidity': date_three_time_five_humidity,
    'date_three_time_five_wind_speed': date_three_time_five_wind_speed,
    'date_three_time_five_direction': date_three_time_five_wind_direction,
    'date_three_time_six': date_three_time_six,
    'date_three_time_six_temp': date_three_time_six_temp,
    'date_three_time_six_temp_min': date_three_time_six_temp_min,
    'date_three_time_six_temp_max': date_three_time_six_temp_max,
    'date_three_time_six_pressure': date_three_time_six_pressure,
    'date_three_time_six_sea_level': date_three_time_six_sea_level,
    'date_three_time_six_grnd_level': date_three_time_six_grnd_level,
    'date_three_time_six_humidity': date_three_time_six_humidity,
    'date_three_time_six_wind_speed': date_three_time_six_wind_speed,
    'date_three_time_six_direction': date_three_time_six_wind_direction,
    'date_three_time_seven': date_three_time_seven,
    'date_three_time_seven_temp': date_three_time_seven_temp,
    'date_three_time_seven_temp_min': date_three_time_seven_temp_min,
    'date_three_time_seven_temp_max': date_three_time_seven_temp_max,
    'date_three_time_seven_pressure': date_three_time_seven_pressure,
    'date_three_time_seven_sea_level': date_three_time_seven_sea_level,
    'date_three_time_seven_grnd_level': date_three_time_seven_grnd_level,
    'date_three_time_seven_humidity': date_three_time_seven_humidity,
    'date_three_time_seven_wind_speed': date_three_time_seven_wind_speed,
    'date_three_time_seven_direction': date_three_time_seven_wind_direction,
    'date_three_time_eight': date_three_time_eight,
    'date_three_time_eight_temp': date_three_time_eight_temp,
    'date_three_time_eight_temp_min': date_three_time_eight_temp_min,
    'date_three_time_eight_temp_max': date_three_time_eight_temp_max,
    'date_three_time_eight_pressure': date_three_time_eight_pressure,
    'date_three_time_eight_sea_level': date_three_time_eight_sea_level,
    'date_three_time_eight_grnd_level': date_three_time_eight_grnd_level,
    'date_three_time_eight_humidity': date_three_time_eight_humidity,
    'date_three_time_eight_wind_speed': date_three_time_eight_wind_speed,
    'date_three_time_eight_direction': date_three_time_eight_wind_direction,
    'date_four_time_one': date_four_time_one,
    'date_four_time_one_temp': date_four_time_one_temp,
    'date_four_time_one_temp_min': date_four_time_one_temp_min,
    'date_four_time_one_temp_max': date_four_time_one_temp_max,
    'date_four_time_one_pressure': date_four_time_one_pressure,
    'date_four_time_one_sea_level': date_four_time_one_sea_level,
    'date_four_time_one_grnd_level': date_four_time_one_grnd_level,
    'date_four_time_one_humidity': date_four_time_one_humidity,
    'date_four_time_one_wind_speed': date_four_time_one_wind_speed,
    'date_four_time_one_direction': date_four_time_one_wind_direction,
    'date_four_time_two': date_four_time_two,
    'date_four_time_two_temp': date_four_time_two_temp,
    'date_four_time_two_temp_min': date_four_time_two_temp_min,
    'date_four_time_two_temp_max': date_four_time_two_temp_max,
    'date_four_time_two_pressure': date_four_time_two_pressure,
    'date_four_time_two_sea_level': date_four_time_two_sea_level,
    'date_four_time_two_grnd_level': date_four_time_two_grnd_level,
    'date_four_time_two_humidity': date_four_time_two_humidity,
    'date_four_time_two_wind_speed': date_four_time_two_wind_speed,
    'date_four_time_two_direction': date_four_time_two_wind_direction,
    'date_four_time_three': date_four_time_three,
    'date_four_time_three_temp': date_four_time_three_temp,
    'date_four_time_three_temp_min': date_four_time_three_temp_min,
    'date_four_time_three_temp_max': date_four_time_three_temp_max,
    'date_four_time_three_pressure': date_four_time_three_pressure,
    'date_four_time_three_sea_level': date_four_time_three_sea_level,
    'date_four_time_three_grnd_level': date_four_time_three_grnd_level,
    'date_four_time_three_humidity': date_four_time_three_humidity,
    'date_four_time_three_wind_speed': date_four_time_three_wind_speed,
    'date_four_time_three_direction': date_four_time_three_wind_direction,
    'date_four_time_four': date_four_time_four,
    'date_four_time_four_temp': date_four_time_four_temp,
    'date_four_time_four_temp_min': date_four_time_four_temp_min,
    'date_four_time_four_temp_max': date_four_time_four_temp_max,
    'date_four_time_four_pressure': date_four_time_four_pressure,
    'date_four_time_four_sea_level': date_four_time_four_sea_level,
    'date_four_time_four_grnd_level': date_four_time_four_grnd_level,
    'date_four_time_four_humidity': date_four_time_four_humidity,
    'date_four_time_four_wind_speed': date_four_time_four_wind_speed,
    'date_four_time_four_direction': date_four_time_four_wind_direction,
    'date_four_time_five': date_four_time_five,
    'date_four_time_five_temp': date_four_time_five_temp,
    'date_four_time_five_temp_min': date_four_time_five_temp_min,
    'date_four_time_five_temp_max': date_four_time_five_temp_max,
    'date_four_time_five_pressure': date_four_time_five_pressure,
    'date_four_time_five_sea_level': date_four_time_five_sea_level,
    'date_four_time_five_grnd_level': date_four_time_five_grnd_level,
    'date_four_time_five_humidity': date_four_time_five_humidity,
    'date_four_time_five_wind_speed': date_four_time_five_wind_speed,
    'date_four_time_five_direction': date_four_time_five_wind_direction,
    'date_four_time_six': date_four_time_six,
    'date_four_time_six_temp': date_four_time_six_temp,
    'date_four_time_six_temp_min': date_four_time_six_temp_min,
    'date_four_time_six_temp_max': date_four_time_six_temp_max,
    'date_four_time_six_pressure': date_four_time_six_pressure,
    'date_four_time_six_sea_level': date_four_time_six_sea_level,
    'date_four_time_six_grnd_level': date_four_time_six_grnd_level,
    'date_four_time_six_humidity': date_four_time_six_humidity,
    'date_four_time_six_wind_speed': date_four_time_six_wind_speed,
    'date_four_time_six_direction': date_four_time_six_wind_direction,
    'date_four_time_seven': date_four_time_seven,
    'date_four_time_seven_temp': date_four_time_seven_temp,
    'date_four_time_seven_temp_min': date_four_time_seven_temp_min,
    'date_four_time_seven_temp_max': date_four_time_seven_temp_max,
    'date_four_time_seven_pressure': date_four_time_seven_pressure,
    'date_four_time_seven_sea_level': date_four_time_seven_sea_level,
    'date_four_time_seven_grnd_level': date_four_time_seven_grnd_level,
    'date_four_time_seven_humidity': date_four_time_seven_humidity,
    'date_four_time_seven_wind_speed': date_four_time_seven_wind_speed,
    'date_four_time_seven_direction': date_four_time_seven_wind_direction,
    'date_four_time_eight': date_four_time_eight,
    'date_four_time_eight_temp': date_four_time_eight_temp,
    'date_four_time_eight_temp_min': date_four_time_eight_temp_min,
    'date_four_time_eight_temp_max': date_four_time_eight_temp_max,
    'date_four_time_eight_pressure': date_four_time_eight_pressure,
    'date_four_time_eight_sea_level': date_four_time_eight_sea_level,
    'date_four_time_eight_grnd_level': date_four_time_eight_grnd_level,
    'date_four_time_eight_humidity': date_four_time_eight_humidity,
    'date_four_time_eight_wind_speed': date_four_time_eight_wind_speed,
    'date_four_time_eight_direction': date_four_time_eight_wind_direction,
    'date_five_time_one': date_five_time_one,
    'date_five_time_one_temp': date_five_time_one_temp,
    'date_five_time_one_temp_min': date_five_time_one_temp_min,
    'date_five_time_one_temp_max': date_five_time_one_temp_max,
    'date_five_time_one_pressure': date_five_time_one_pressure,
    'date_five_time_one_sea_level': date_five_time_one_sea_level,
    'date_five_time_one_grnd_level': date_five_time_one_grnd_level,
    'date_five_time_one_humidity': date_five_time_one_humidity,
    'date_five_time_one_wind_speed': date_five_time_one_wind_speed,
    'date_five_time_one_direction': date_five_time_one_wind_direction,
    'date_five_time_two': date_five_time_two,
    'date_five_time_two_temp': date_five_time_two_temp,
    'date_five_time_two_temp_min': date_five_time_two_temp_min,
    'date_five_time_two_temp_max': date_five_time_two_temp_max,
    'date_five_time_two_pressure': date_five_time_two_pressure,
    'date_five_time_two_sea_level': date_five_time_two_sea_level,
    'date_five_time_two_grnd_level': date_five_time_two_grnd_level,
    'date_five_time_two_humidity': date_five_time_two_humidity,
    'date_five_time_two_wind_speed': date_five_time_two_wind_speed,
    'date_five_time_two_direction': date_five_time_two_wind_direction,
    'date_five_time_three': date_five_time_three,
    'date_five_time_three_temp': date_five_time_three_temp,
    'date_five_time_three_temp_min': date_five_time_three_temp_min,
    'date_five_time_three_temp_max': date_five_time_three_temp_max,
    'date_five_time_three_pressure': date_five_time_three_pressure,
    'date_five_time_three_sea_level': date_five_time_three_sea_level,
    'date_five_time_three_grnd_level': date_five_time_three_grnd_level,
    'date_five_time_three_humidity': date_five_time_three_humidity,
    'date_five_time_three_wind_speed': date_five_time_three_wind_speed,
    'date_five_time_three_direction': date_five_time_three_wind_direction,
    'date_five_time_four': date_five_time_four,
    'date_five_time_four_temp': date_five_time_four_temp,
    'date_five_time_four_temp_min': date_five_time_four_temp_min,
    'date_five_time_four_temp_max': date_five_time_four_temp_max,
    'date_five_time_four_pressure': date_five_time_four_pressure,
    'date_five_time_four_sea_level': date_five_time_four_sea_level,
    'date_five_time_four_grnd_level': date_five_time_four_grnd_level,
    'date_five_time_four_humidity': date_five_time_four_humidity,
    'date_five_time_four_wind_speed': date_five_time_four_wind_speed,
    'date_five_time_four_direction': date_five_time_four_wind_direction,
    'date_five_time_five': date_five_time_five,
    'date_five_time_five_temp': date_five_time_five_temp,
    'date_five_time_five_temp_min': date_five_time_five_temp_min,
    'date_five_time_five_temp_max': date_five_time_five_temp_max,
    'date_five_time_five_pressure': date_five_time_five_pressure,
    'date_five_time_five_sea_level': date_five_time_five_sea_level,
    'date_five_time_five_grnd_level': date_five_time_five_grnd_level,
    'date_five_time_five_humidity': date_five_time_five_humidity,
    'date_five_time_five_wind_speed': date_five_time_five_wind_speed,
    'date_five_time_five_direction': date_five_time_five_wind_direction,
    'date_five_time_six': date_five_time_six,
    'date_five_time_six_temp': date_five_time_six_temp,
    'date_five_time_six_temp_min': date_five_time_six_temp_min,
    'date_five_time_six_temp_max': date_five_time_six_temp_max,
    'date_five_time_six_pressure': date_five_time_six_pressure,
    'date_five_time_six_sea_level': date_five_time_six_sea_level,
    'date_five_time_six_grnd_level': date_five_time_six_grnd_level,
    'date_five_time_six_humidity': date_five_time_six_humidity,
    'date_five_time_six_wind_speed': date_five_time_six_wind_speed,
    'date_five_time_six_direction': date_five_time_six_wind_direction, 
    'date_five_time_seven': date_five_time_seven,
    'date_five_time_seven_temp': date_five_time_seven_temp,
    'date_five_time_seven_temp_min': date_five_time_seven_temp_min,
    'date_five_time_seven_temp_max': date_five_time_seven_temp_max,
    'date_five_time_seven_pressure': date_five_time_seven_pressure,
    'date_five_time_seven_sea_level': date_five_time_seven_sea_level,
    'date_five_time_seven_grnd_level': date_five_time_seven_grnd_level,
    'date_five_time_seven_humidity': date_five_time_seven_humidity,
    'date_five_time_seven_wind_speed': date_five_time_seven_wind_speed,
    'date_five_time_seven_direction': date_five_time_seven_wind_direction,
    'date_five_time_eight': date_five_time_eight,
    'date_five_time_eight_temp': date_five_time_eight_temp,
    'date_five_time_eight_temp_min': date_five_time_eight_temp_min,
    'date_five_time_eight_temp_max': date_five_time_eight_temp_max,
    'date_five_time_eight_pressure': date_five_time_eight_pressure,
    'date_five_time_eight_sea_level': date_five_time_eight_sea_level,
    'date_five_time_eight_grnd_level': date_five_time_eight_grnd_level,
    'date_five_time_eight_humidity': date_five_time_eight_humidity,
    'date_five_time_eight_wind_speed': date_five_time_eight_wind_speed,
    'date_five_time_eight_direction': date_five_time_eight_wind_direction 

}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-e793e068d737> in <module>
#     409
#     410 }
# --> 411 weather_data = pd.DataFrame(weather_dict)
#     412 weather_data.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# ...

# %%
weather_data.to_csv('weather_quito4.csv')

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["city_name"], weather_data["date_one_time_one_temp"], marker="o")

# Incorporate the other graph properties
plt.title("Temperature in World Cities")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()
